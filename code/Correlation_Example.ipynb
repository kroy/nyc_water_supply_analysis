# %%
# !pip install meteostat
# Out:
# Requirement already satisfied: meteostat in c:\users\mp5160\anaconda3\envs\uda\lib\site-packages (1.7.4)
# Requirement already satisfied: pandas>=2 in c:\users\mp5160\anaconda3\envs\uda\lib\site-packages (from meteostat) (2.2.2)
# Requirement already satisfied: pytz in c:\users\mp5160\anaconda3\envs\uda\lib\site-packages (from meteostat) (2024.1)
# Requirement already satisfied: numpy in c:\users\mp5160\anaconda3\envs\uda\lib\site-packages (from meteostat) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mp5160\anaconda3\envs\uda\lib\site-packages (from pandas>=2->meteostat) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mp5160\anaconda3\envs\uda\lib\site-packages (from pandas>=2->meteostat) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mp5160\anaconda3\envs\uda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2->meteostat) (1.16.0)

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import seaborn as sns
import pandas as pd

# %%
fpath_ridership = r'D:\Hunter College Dropbox\Mehdi Pourpeikari Heris\Teaching\Urban_Data_Analsysis\Summer_2025\Datasets\MTA_Daily_Ridership_Data__2020_-_2025_20250729.csv'

# %%
# Set time period
start = datetime(2024, 1, 1)
end = datetime(2024, 12, 31)

# Create Point for NYC
nyc = Point(42.34389081165582, -71.07208866602299)

# Get daily data for 2024
data = Daily(nyc, start, end)
df_weather = data.fetch()

# Plot line chart including average, minimum and maximum temperature
df_weather.plot(y=['tavg', 'tmin', 'tmax'])
# Out:
# <Axes: xlabel='time'>

# %%
df_weather.reset_index(inplace=True)
df_weather['Date_dt'] = pd.to_datetime(df_weather['time'])
df_weather.sample()
# Out:
#     index       time  tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  \
# 92     92 2024-04-02   6.2   4.4   8.9   0.5  <NA>  <NA>  18.0  <NA>  1016.4
#
#     tsun    Date_dt
# 92  <NA> 2024-04-02

# %%
df_transit = pd.read_csv(fpath_ridership)
df_transit['Date_dt'] = pd.to_datetime(df_transit['Date'])
df_transit = df_transit.loc[df_transit['Date_dt'].dt.year==2024]
df_transit.sample()
# Out:
#             Date  Subways: Total Estimated Ridership  \
# 1756  12/21/2024                             2645323
#
#       Subways: % of Comparable Pre-Pandemic Day  \
# 1756                                        0.8
#
#       Buses: Total Estimated Ridership  \
# 1756                            788267
#
#       Buses: % of Comparable Pre-Pandemic Day  \
# 1756                                     0.62
#
#       LIRR: Total Estimated Ridership  LIRR: % of Comparable Pre-Pandemic Day  \
# 1756                           147327                                    1.15
#
#       Metro-North: Total Estimated Ridership  \
# 1756                                  138248
#
#       Metro-North: % of Comparable Pre-Pandemic Day  \
# 1756                                           0.88
#
#       Access-A-Ride: Total Scheduled Trips  \
# 1756                                 23289
#
#       Access-A-Ride: % of Comparable Pre-Pandemic Day  \
# 1756                                             1.35
#
#       Bridges and Tunnels: Total Traffic  \
# 1756                              898683
#
#       Bridges and Tunnels: % of Comparable Pre-Pandemic Day  \
# 1756                                               1.02
#
#       Staten Island Railway: Total Estimated Ridership  \
# 1756                                              2973
#
#       Staten Island Railway: % of Comparable Pre-Pandemic Day    Date_dt
# 1756                                                0.6       2024-12-21
